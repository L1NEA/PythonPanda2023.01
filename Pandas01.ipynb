# %% [markdown]
# <a href="https://colab.research.google.com/github/L1NEA/PythonPanda2023.01/blob/ExemplosDeAula/Pandas01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Primeiro exemplo de manipulação de dados usando Python Pandas**
#
# Autor: Aline Cerqueira
#
# Data: 06 de fevereiro de 2023

# %%
# para instalar a biblioteca do Pandas:
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Importando Biblioteca Pandas no Python (não é uma biblioteca nativa do Python; o Colab ja tem ela instalada por padrão, mas em um IDE Local precisa instalar a biblioteca)

import pandas as pd

combustiveis_df = pd.read_excel("ca-2021-02.xlsx")

# %%
# Usa o print para ver o dataframe!

print(combustiveis_df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
display (combustiveis_df)
# Out:
#        Regiao - Sigla Estado - Sigla  Municipio  \
# 0                  NE             AL  ARAPIRACA
# 1                  NE             AL  ARAPIRACA
# 2                  NE             AL  ARAPIRACA
# 3                  NE             AL  ARAPIRACA
# 4                  NE             AL  ARAPIRACA
# ...               ...            ...        ...
# 168404             NE             BA     JEQUIE
# 168405             SE             MG  ITUIUTABA
# 168406             SE             MG  ITUIUTABA
# 168407             SE             MG  ITUIUTABA
# 168408             SE             MG  ITUIUTABA
#
#                                            Revenda      CNPJ da Revenda  \
# 0                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 1                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 2                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# 3                             POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
# Exibe as primeiras 5 linhas

display (combustiveis_df.head())
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# ...

# %%
# Quero na verdade exibir as 15 primeiras linhas
display (combustiveis_df.head(15))
# Out:
#    Regiao - Sigla Estado - Sigla        Municipio  \
# 0              NE             AL        ARAPIRACA
# 1              NE             AL        ARAPIRACA
# 2              NE             AL        ARAPIRACA
# 3              NE             AL        ARAPIRACA
# 4              NE             AL        ARAPIRACA
# 5              NE             AL  DELMIRO GOUVEIA
# 6              NE             AL  DELMIRO GOUVEIA
# 7              NE             AL  DELMIRO GOUVEIA
# 8              NE             AL  DELMIRO GOUVEIA
# 9              NE             AL  DELMIRO GOUVEIA
# 10             NE             AL  DELMIRO GOUVEIA
# 11             NE             AL  DELMIRO GOUVEIA
# 12             NE             AL  DELMIRO GOUVEIA
# 13             NE             AL  DELMIRO GOUVEIA
# 14             NE             AL  DELMIRO GOUVEIA
#
#                                   Revenda      CNPJ da Revenda  \
# 0                    POSTO ARAPIRACA LTDA   12.451.076/0004-65
# ...

# %%
# Comand Dataframe.shape

print (combustiveis_df.shape)
# Saída = número de linhas, número de colunas

print (combustiveis_df.shape[0])
# Saída = só o número de linhas

print (combustiveis_df.shape[1])
# Saída = só o número de colunas
# Out:
# (168409, 16)
# 168409
# 16

# %%
# Mostra as colunas (nomes) e que tipo de dados cada uma tem

print (combustiveis_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168409 entries, 0 to 168408
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     168409 non-null  object
#  1   Estado - Sigla     168409 non-null  object
#  2   Municipio          168409 non-null  object
#  3   Revenda            168409 non-null  object
#  4   CNPJ da Revenda    168409 non-null  object
#  5   Nome da Rua        168409 non-null  object
#  6   Numero Rua         168353 non-null  object
#  7   Complemento        35057 non-null   object
#  8   Bairro             168043 non-null  object
#  9   Cep                168409 non-null  object
#  10  Produto            168409 non-null  object
#  11  Data da Coleta     168409 non-null  datetime64[ns]
#  12  Valor de Venda     168409 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  168409 non-null  object
# ...

# %%
# Comando Dataframe.describe()

display (combustiveis_df.describe())

# Saída = estatisticas mais básicas do Dataframe (somente informações numéricas) (Contagem de linhas, média, desvio padrão, "parcelas" e máximo)
# Out:
#        Valor de Venda  Valor de Compra
# count   168409.000000              0.0
# mean         6.005184              NaN
# std          0.794541              NaN
# min          2.849000              NaN
# 25%          5.339000              NaN
# 50%          5.859000              NaN
# 75%          6.699000              NaN
# max          8.990000              NaN

# %%
# Filtrar apenas por uma coluna

display(combustiveis_df['Revenda'])
# Out:
# 0                               POSTO ARAPIRACA LTDA
# 1                               POSTO ARAPIRACA LTDA
# 2                               POSTO ARAPIRACA LTDA
# 3                               POSTO ARAPIRACA LTDA
# 4                               POSTO ARAPIRACA LTDA
#                              ...
# 168404    COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA
# 168405             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168406             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168407             ABC DISTRIBUICAO DE PETROLEO LTDA
# 168408             ABC DISTRIBUICAO DE PETROLEO LTDA
# Name: Revenda, Length: 168409, dtype: object

# %%
# Criar um novo Dataframe apenas com as colunas que eu quero de outro Dataframe

ca_df = combustiveis_df[['Revenda','Municipio','Produto','Valor de Venda']]
display (ca_df)
# Out:
#                                            Revenda  Municipio  \
# 0                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 1                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 2                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 3                             POSTO ARAPIRACA LTDA  ARAPIRACA
# 4                             POSTO ARAPIRACA LTDA  ARAPIRACA
# ...                                            ...        ...
# 168404  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA     JEQUIE
# 168405           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168406           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168407           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
# 168408           ABC DISTRIBUICAO DE PETROLEO LTDA  ITUIUTABA
#
#                    Produto  Valor de Venda
# 0                 GASOLINA           6.799
# 1                   ETANOL           5.299
# 2                   DIESEL           5.549
# 3       GASOLINA ADITIVADA           6.899
# ...

# %%
# Exibe a 4ª linha

display (ca_df.loc[3])
# Out:
# Revenda           POSTO ARAPIRACA LTDA
# Municipio                    ARAPIRACA
# Produto             GASOLINA ADITIVADA
# Valor de Venda                   6.899
# Name: 3, dtype: object

# %%
# Exibir da 10ª linha até a 20ª linha

display(ca_df.loc[9:19])
# Out:
#                                   Revenda        Municipio  \
# 9          AUTO POSTO FREITAS & MAIA LTDA  DELMIRO GOUVEIA
# 10               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA
# 11               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA
# 12               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA
# 13               AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA
# 14  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 15  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 16  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 17  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 18  COMERCIO DE COMBUSTIVEIS NENZITA LTDA  DELMIRO GOUVEIA
# 19         MARCOS ANTONIO DA SILVA CABRAL      ITACOATIARA
#
#                Produto  Valor de Venda
# 9           DIESEL S10           5.983
# 10            GASOLINA           7.197
# 11              ETANOL           5.987
# 12              DIESEL           5.978
# 13          DIESEL S10           5.989
# ...

# %%
# Exibir da 2ª linha até a 10ª pulando de 2 em 2

display(ca_df.loc[2:10:2])
# Out:
#                            Revenda        Municipio             Produto  \
# 2             POSTO ARAPIRACA LTDA        ARAPIRACA              DIESEL
# 4             POSTO ARAPIRACA LTDA        ARAPIRACA          DIESEL S10
# 6   AUTO POSTO FREITAS & MAIA LTDA  DELMIRO GOUVEIA              ETANOL
# 8   AUTO POSTO FREITAS & MAIA LTDA  DELMIRO GOUVEIA  GASOLINA ADITIVADA
# 10        AUTO POSTO DA PEDRA LTDA  DELMIRO GOUVEIA            GASOLINA
#
#     Valor de Venda
# 2            5.549
# 4            5.649
# 6            5.982
# 8            7.208
# 10           7.197

# %%
# Criar um dataframe gas_df contendo apenas as 4 colunas (Revenda, Municipio, Produto, Valor de Venda) somente com combustivel sendo GASOLINA e exibir na tela

gas_df = ca_df.loc[ca_df['Produto'] == 'GASOLINA']
display (gas_df)
# Out:
#                                                   Revenda  \
# 0                                    POSTO ARAPIRACA LTDA
# 5                          AUTO POSTO FREITAS & MAIA LTDA
# 10                               AUTO POSTO DA PEDRA LTDA
# 14                  COMERCIO DE COMBUSTIVEIS NENZITA LTDA
# 19                         MARCOS ANTONIO DA SILVA CABRAL
# ...                                                   ...
# 168392                           AUTO POSTO KM BAURU LTDA
# 168394      COOPERCITRUS COOPERATIVA DE PRODUTORES RURAIS
# 168399  VICMAR COMERCIO DE COMBUSTIVEIS E LUBRIFICANTE...
# 168403         COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA
# 168405                  ABC DISTRIBUICAO DE PETROLEO LTDA
#
#                     Municipio   Produto  Valor de Venda
# 0                   ARAPIRACA  GASOLINA           6.799
# 5             DELMIRO GOUVEIA  GASOLINA           7.198
# 10            DELMIRO GOUVEIA  GASOLINA           7.197
# ...

# %%
# Mostrar o valor da gasolina mais cara

display (gas_df['Valor de Venda'].max())
# Out:
# 7.999

# %%
# Mostrar posto e municipio da gasolina mais cara

display(gas_df[['Revenda', 'Municipio', 'Valor de Venda']].max())
# Out:
# Revenda           ZV POSTO DE SERVIÇO LTDA.
# Municipio                           XANXERE
# Valor de Venda                        7.999
# dtype: object

# %%
# Dataframe.loc[] com multiplas condições para filtragem

# Quais são os preços dos postos que vendem ETANOL na cidade de SANTO ANDRE ordenado do menor -> maior

etanol_santoandre_df = ca_df.loc[(ca_df ['Produto'] == 'ETANOL') & (ca_df ['Municipio'] == 'SANTO ANDRE')]
display (etanol_santoandre_df.sort_values(by='Valor de Venda'))
# Out:
#                                                   Revenda    Municipio  \
# 151696                        AUTO POSTO CENTREVILLE LTDA  SANTO ANDRE
# 135731                    AUTO POSTO X6 SANTO ANDRÉ LTDA.  SANTO ANDRE
# 136302                         PATTO ROSA AUTO POSTO LTDA  SANTO ANDRE
# 133248  POSTO DE SERVICOS REQUINTE COMERCIO DE COMBUST...  SANTO ANDRE
# 154565                 AUTO POSTO CAPITAO BRASIL II LTDA.  SANTO ANDRE
# ...                                                   ...          ...
# 77056                           ALVORECER AUTO POSTO LTDA  SANTO ANDRE
# 77061                                 AUTO POSTO DON PEPE  SANTO ANDRE
# 1519                         AUTO POSTO ALEMAO LTDA - EPP  SANTO ANDRE
# 43572                        AUTO POSTO ALEMAO LTDA - EPP  SANTO ANDRE
# 20235                                 AUTO POSTO DON PEPE  SANTO ANDRE
#
#        Produto  Valor de Venda
# 151696  ETANOL           4.489
# 135731  ETANOL           4.499
# ...

# %%
# Qual é a média de preço dos combustíveis GASOLINA e GASOLINA ADITIVADA do bairro VILA FORMOSA em SÃO PAULO
display (combustiveis_df.loc[(combustiveis_df['Bairro'] == 'VILA FORMOSA') &
                             (combustiveis_df ['Municipio'] == 'SAO PAULO') &
                             ((combustiveis_df ['Produto'] == 'GASOLINA') | (combustiveis_df ['Produto'] == 'GASOLINA ADITIVADA')),
                             ['Valor de Venda']].mean())
# Out:
# Valor de Venda    6.501764
# dtype: float64

# %%
# Como mostrar média de valor POR COMBUSTÍVEL

media_por_combustivel_df = ca_df[['Produto','Valor de Venda']].groupby(by= 'Produto').mean().round(2)
display(media_por_combustivel_df)
# Out:
#                     Valor de Venda
# Produto
# DIESEL                        5.38
# DIESEL S10                    5.45
# ETANOL                        5.46
# GASOLINA                      6.71
# GASOLINA ADITIVADA            6.86
# GNV                           4.39

# %%
# Adicionar uma coluna de valor booleano no combustiveis_df chamada "Ativo" que, por padrão, vai ser True para TODAS as linhas

combustiveis_df ['Ativo'] = True
print (combustiveis_df.info())
display (combustiveis_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168409 entries, 0 to 168408
# Data columns (total 17 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Regiao - Sigla     168409 non-null  object
#  1   Estado - Sigla     168409 non-null  object
#  2   Municipio          168409 non-null  object
#  3   Revenda            168409 non-null  object
#  4   CNPJ da Revenda    168409 non-null  object
#  5   Nome da Rua        168409 non-null  object
#  6   Numero Rua         168353 non-null  object
#  7   Complemento        35057 non-null   object
#  8   Bairro             168043 non-null  object
#  9   Cep                168409 non-null  object
#  10  Produto            168409 non-null  object
#  11  Data da Coleta     168409 non-null  datetime64[ns]
#  12  Valor de Venda     168409 non-null  float64
#  13  Valor de Compra    0 non-null       float64
#  14  Unidade de Medida  168409 non-null  object
# ...

# %%
# Criar uma coluna nova chamada "Obs" que preencha automaticamente "MELHOR CIDADE" quando o municipio for SAO PAULO

combustiveis_df['Obs'] = ["Melhor Cidade" if municipio == 'SAO PAULO' else '' for municipio in combustiveis_df['Municipio']]
display(combustiveis_df.loc[combustiveis_df['Municipio'].isin(['SAO PAULO', 'CAMPINAS', 'SALTO']), ['Municipio', 'Obs']])
# Out:
#         Municipio            Obs
# 1601    SAO PAULO  Melhor Cidade
# 1602    SAO PAULO  Melhor Cidade
# 1603    SAO PAULO  Melhor Cidade
# 1604    SAO PAULO  Melhor Cidade
# 2607     CAMPINAS
# ...           ...            ...
# 165925  SAO PAULO  Melhor Cidade
# 165926  SAO PAULO  Melhor Cidade
# 166122  SAO PAULO  Melhor Cidade
# 166123  SAO PAULO  Melhor Cidade
# 166124  SAO PAULO  Melhor Cidade
#
# [7180 rows x 2 columns]

# %%
# Exportar para excel o dataframe com etanol em Santo Andre
etanol_santoandre_df.to_excel('etanol_santoandre.xlsx', sheet_name = 'Etanol em Santo Andre')

# %%
# Importar biblioteca numpy

import numpy as np

# %%
# Como preencher uma coluna 'Valor de venda - Status' que verifica: se valor de venda for maior que R$6,5 ele indica "Caro", se menor indica "Barato"

combustiveis_df['Status - Valor de Venda'] = np.where (combustiveis_df['Valor de Venda'] > 6.5, 'Caro', 'Barato')
display(combustiveis_df[['Revenda', 'Valor de Venda', 'Status - Valor de Venda']])
# Out:
#                                            Revenda  Valor de Venda  \
# 0                             POSTO ARAPIRACA LTDA           6.799
# 1                             POSTO ARAPIRACA LTDA           5.299
# 2                             POSTO ARAPIRACA LTDA           5.549
# 3                             POSTO ARAPIRACA LTDA           6.899
# 4                             POSTO ARAPIRACA LTDA           5.649
# ...                                            ...             ...
# 168404  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA           5.859
# 168405           ABC DISTRIBUICAO DE PETROLEO LTDA           6.580
# 168406           ABC DISTRIBUICAO DE PETROLEO LTDA           4.740
# 168407           ABC DISTRIBUICAO DE PETROLEO LTDA           5.448
# 168408           ABC DISTRIBUICAO DE PETROLEO LTDA           6.580
#
#        Status - Valor de Venda
# 0                         Caro
# 1                       Barato
# 2                       Barato
# 3                         Caro
# ...

# %% [markdown]
# # **Calcular o número de postos de gasolina por habitantes temos na amostragem de combustiveis nov/2021**

# %%
# Renomear colunas

num_habitantes_df = pd.read_csv("ibge_num_habitantes_estimado.csv", sep=";")
num_habitantes_df.rename (columns={"Estado" : "Estado - Sigla"}, inplace=True)
display (num_habitantes_df)
# Out:
#          Municipio Estado - Sigla  NumHabitantes2021
# 0   BELO HORIZONTE             MG            2530701
# 1         CAMPINAS             SP            1223237
# 2     CAMPO GRANDE             MS             916001
# 3         CURITIBA             PR            1963726
# 4          GOIANIA             GO            1555626
# 5       INDAIATUBA             SP             260690
# 6            NATAL             RN             803739
# 7           PALMAS             TO             313349
# 8        PENAPOLIS             SP              64098
# 9     PORTO ALEGRE             RS            1492530
# 10     PORTO VELHO             RO             548952
# 11      RIO BRANCO             AC             419452
# 12  RIO DE JANEIRO             RJ            6775561
# 13    SALTO GRANDE             SP               9396
# 14          SANTOS             SP             433991
# 15       SAO PAULO             SP           12396372
# 16     SAO VICENTE             SP             370839
# ...

# %%
# Fazer um MERGE de dois dataframes em outro dataframe

merge_df = combustiveis_df.merge (num_habitantes_df, how="inner", on=['Municipio', 'Estado - Sigla'])
display (merge_df)
print(merge_df.info())
# Out:
#       Regiao - Sigla Estado - Sigla   Municipio  \
# 0                 CO             GO     GOIANIA
# 1                 CO             GO     GOIANIA
# 2                 CO             GO     GOIANIA
# 3                 CO             GO     GOIANIA
# 4                 CO             GO     GOIANIA
# ...              ...            ...         ...
# 20629             SE             SP  INDAIATUBA
# 20630             SE             SP  INDAIATUBA
# 20631             SE             SP  INDAIATUBA
# 20632             SE             SP  INDAIATUBA
# 20633             SE             SP  INDAIATUBA
#
#                                          Revenda      CNPJ da Revenda  \
# 0                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 1                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 2                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 3                              POSTO DO BOI LTDA   06.880.293/0001-25
# ...

# %%
#Destruir coluna completamente vazia (todas as linhas são nulas)

merge_df.dropna(axis='columns', inplace=True)
print(merge_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Regiao - Sigla           20634 non-null  object
#  1   Estado - Sigla           20634 non-null  object
#  2   Municipio                20634 non-null  object
#  3   Revenda                  20634 non-null  object
#  4   CNPJ da Revenda          20634 non-null  object
#  5   Nome da Rua              20634 non-null  object
#  6   Numero Rua               20634 non-null  object
#  7   Bairro                   20634 non-null  object
#  8   Cep                      20634 non-null  object
#  9   Produto                  20634 non-null  object
#  10  Data da Coleta           20634 non-null  datetime64[ns]
#  11  Valor de Venda           20634 non-null  float64
#  12  Unidade de Medida        20634 non-null  object
# ...

# %%
#Destruir colunas que estiverem completamente vazias (todas as linhas são nulas)

merge_df.dropna(axis='columns', inplace=True)
print(merge_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Regiao - Sigla           20634 non-null  object
#  1   Estado - Sigla           20634 non-null  object
#  2   Municipio                20634 non-null  object
#  3   Revenda                  20634 non-null  object
#  4   CNPJ da Revenda          20634 non-null  object
#  5   Nome da Rua              20634 non-null  object
#  6   Numero Rua               20634 non-null  object
#  7   Bairro                   20634 non-null  object
#  8   Cep                      20634 non-null  object
#  9   Produto                  20634 non-null  object
#  10  Data da Coleta           20634 non-null  datetime64[ns]
#  11  Valor de Venda           20634 non-null  float64
#  12  Unidade de Medida        20634 non-null  object
# ...

# %%
# Excluir colunas selecionadas

colunas=['Regiao - Sigla', 'Nome da Rua', 'Numero Rua', 
         'Bairro', 'Cep', 'Produto', 'Data da Coleta', 'Valor de Venda',
         'Unidade de Medida', 'Bandeira', 'Ativo', 'Status - Valor de Venda', 'Obs']

merge_df.drop(labels=colunas, axis=1, inplace=True)
print(merge_df.info())
display (merge_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Estado - Sigla     20634 non-null  object
#  1   Municipio          20634 non-null  object
#  2   Revenda            20634 non-null  object
#  3   CNPJ da Revenda    20634 non-null  object
#  4   NumHabitantes2021  20634 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 967.2+ KB
# None
#       Estado - Sigla   Municipio                                    Revenda  \
# 0                 GO     GOIANIA                  AERO SETE AUTO POSTO LTDA
# 1                 GO     GOIANIA                  AERO SETE AUTO POSTO LTDA
# 2                 GO     GOIANIA                  AERO SETE AUTO POSTO LTDA
# 3                 GO     GOIANIA                          POSTO DO BOI LTDA
# 4                 GO     GOIANIA                          POSTO DO BOI LTDA
# ...

# %%
# Destruir linhas duplicadas

merge_df.drop_duplicates (inplace = True)
display (merge_df.head(100))
# Out:
#      Estado - Sigla       Municipio                                   Revenda  \
# 0                GO         GOIANIA                 AERO SETE AUTO POSTO LTDA
# 3                GO         GOIANIA                         POSTO DO BOI LTDA
# 7                GO         GOIANIA                             POSTO DN LTDA
# 11               GO         GOIANIA                         POSTO ALDEIA LTDA
# 15               GO         GOIANIA               AUTO POSTO SANTA LUZIA LTDA
# ...             ...             ...                                       ...
# 1677             RJ  RIO DE JANEIRO       POSTO SANTA CLARA DA PAVUNA II LTDA
# 1682             RJ  RIO DE JANEIRO          POSTO SANTA CLARA DA PAVUNA LTDA
# 1688             RJ  RIO DE JANEIRO            NOVA PARADINHA AUTO POSTO LTDA
# 1694             RJ  RIO DE JANEIRO            AUTO POSTO LUAR DA PENHA LTDA.
# 1699             RJ  RIO DE JANEIRO  AUTO POSTO FUTURO GNV DE BONSUCESSO LTDA
#
# ...

# %%
# Agrupar e contar quantos postos tem na cidade

postos_por_municipio_df = merge_df.groupby(by=['Estado - Sigla', 'Municipio', 'NumHabitantes2021']).count() #agrupa as informações iguais nessas colunas e conta quantos itens tem
postos_por_municipio_df.drop('CNPJ da Revenda', axis=1, inplace=True) #descartou uma coluna
postos_por_municipio_df.reset_index(inplace=True)
postos_por_municipio_df.rename(columns={"Revenda": "Número de Postos"}, inplace=True) #renomeou uma coluna para trazer a informação desejada
display(postos_por_municipio_df.info())
display(postos_por_municipio_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Estado - Sigla     15 non-null     object
#  1   Municipio          15 non-null     object
#  2   NumHabitantes2021  15 non-null     int64
#  3   Número de Postos   15 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 608.0+ bytes
# None
#    Estado - Sigla       Municipio  NumHabitantes2021  Número de Postos
# 0              AC      RIO BRANCO             419452                44
# 1              GO         GOIANIA            1555626                93
# 2              MG  BELO HORIZONTE            2530701                54
# 3              MS    CAMPO GRANDE             916001               104
# 4              PR        CURITIBA            1963726               110
# 5              RJ  RIO DE JANEIRO            6775561               379
# ...

# %%
# FINAL - **Calcular o número de postos de gasolina por habitantes temos na amostragem de combustiveis nov/2021**

postos_por_municipio_df ['Num Habitantes p/ posto'] =  postos_por_municipio_df['NumHabitantes2021'] / postos_por_municipio_df['Número de Postos']
display (postos_por_municipio_df)
# Out:
#    Estado - Sigla       Municipio  NumHabitantes2021  Número de Postos  \
# 0              AC      RIO BRANCO             419452                44
# 1              GO         GOIANIA            1555626                93
# 2              MG  BELO HORIZONTE            2530701                54
# 3              MS    CAMPO GRANDE             916001               104
# 4              PR        CURITIBA            1963726               110
# 5              RJ  RIO DE JANEIRO            6775561               379
# 6              RN           NATAL             803739                37
# 7              RO     PORTO VELHO             548952                40
# 8              RS    PORTO ALEGRE            1492530                73
# 9              SP        CAMPINAS            1223237                51
# 10             SP      INDAIATUBA             260690                36
# 11             SP          SANTOS             433991                36
# ...

# %%
# GRÁFICOS!!!

import matplotlib.pyplot as plt

plt.hist(combustiveis_df['Valor de Venda'])
# Out:
# (array([2.8000e+01, 6.7200e+02, 2.6370e+03, 3.8035e+04, 4.5319e+04,
#         2.7049e+04, 4.1406e+04, 1.2733e+04, 4.8700e+02, 4.3000e+01]),
#  array([2.849 , 3.4631, 4.0772, 4.6913, 5.3054, 5.9195, 6.5336, 7.1477,
#         7.7618, 8.3759, 8.99  ]),
#  <a list of 10 Patch objects>)

# %%
# Colocar título no gráfico e descrições dos eixos
plt.hist(combustiveis_df['Valor de Venda'])
plt.title("Preço dos combustíveis em nov/2021")
plt.xlabel("Preço ($BRL)")
plt.ylabel("Quantidade de dados coletados")

# Exibe a linha tracejada com o preço médio
plt.axvline(combustiveis_df['Valor de Venda'].mean(), color='red', linestyle='--', linewidth=3)

# Exibe o gráfico
plt.show()

# %%
# Novo gráfico

c_mean = combustiveis_df['Valor de Venda'].groupby(by=combustiveis_df['Produto']).mean()
display(c_mean)
# Out:
# Produto
# DIESEL                5.375682
# DIESEL S10            5.454901
# ETANOL                5.456115
# GASOLINA              6.708741
# GASOLINA ADITIVADA    6.860422
# GNV                   4.392935
# Name: Valor de Venda, dtype: float64

# %%
import seaborn as sns

# Definir a áres do gráfico
plt.figure(figsize=(10,5))

# Configurar o gráfico

c_mean_gráfico = c_mean.plot(
    kind="barh",
    ylabel="Media de preços ($BRL/L)",
    xlabel="Tipo de combustível",
    title="Média de preços por tipo de combustível",
    color="green",
    alpha=0.7 #opacidade
)

c_mean_gráfico.set_ylabel("Media de preços ($BRL/L)")
c_mean_gráfico.set_xlabel("Tipo de combustível")

# Grid
plt.grid(axis="x", alpha=0.7) #grade baseada no eixo x

# Remover as bordas do gráfico
sns.despine()

# Exibir o gráfico
plt.show()

# %%
#c_mean.reset_index(inplace=True)
display(c_mean)

excel = "por_litro.xlsx"
c_mean.to_excel(excel, "Sumário")
# Out:
# Produto
# DIESEL                5.375682
# DIESEL S10            5.454901
# ETANOL                5.456115
# GASOLINA              6.708741
# GASOLINA ADITIVADA    6.860422
# GNV                   4.392935
# Name: Valor de Venda, dtype: float64

# %%
# Vamos personalizar a planilha Excel

from openpyxl import load_workbook
from openpyxl.styles import PatternFill, Font, Color, Alignment

# vai abrir o Excel no openpyxl
wb = load_workbook(excel) # wb = workbook

# Pegar a planilha certa usando o SheetName 
ws = wb['Sumário'] # ws = worksheet

# Pintar o cabeçalho da tabela de cinza claro
cinza_claro = PatternFill("solid", fgColor="cccccc")
coords = ['A1', 'B1']
for coord in coords : ws[coord].fill = cinza_claro

# Onde o preço do combustível for maior ou igual a R$6,5 pinta a fonte de vermelho e deixa negrito
MAX_ROW = ws.max_row
num_linha = 2
while (num_linha <= MAX_ROW) :
  coord = 'B' + str(num_linha)  #coord= "B{0}".format(num_linha)
  if ws [coord].value >= 6.5:
    ws[coord].font = Font(bold=True, color="FF0000")
  num_linha = num_linha + 1

#Salvar o Excel
wb.save(excel)
